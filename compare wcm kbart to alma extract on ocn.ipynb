# %%
import pandas as pd

# %%
wcm = pd.read_csv('6569_wiley.rcp_kbart.txt', sep='\t')

# %%
wcm2 = wcm[['publication_title', 'title_url', 'oclc_number']]
wcm2
# Out:
#                                       publication_title  \
# 0     Hydrophobia : M. Pasteur and his methods : a c...
# 1     Oratio panegyrica pro musis Hanovicis instaura...
# 2     Studies in surgical pathological physiology fr...
# 3     Procentische, chemische zusammensetzung der na...
# 4                         Common membranous sore throat
# ...                                                 ...
# 6689  Report of the Departmental Committee appointed...
# 6690  Beitraege zur Kenntniss der normalen und patho...
# 6691  Discussion sur le typhus observé dans les arm...
# 6692         Proceedings of the Royal Society of London
# 6693  A history of nitrous oxide and oxygen anaesthesia
#
#                                               title_url  oclc_number
# 0     https://app.wileydigitalarchives.com/wiley/det...   1159470629
# 1     https://app.wileydigitalarchives.com/wiley/det...   1159507163
# 2     https://app.wileydigitalarchives.com/wiley/det...   1159573078
# ...

# %%
alma = pd.read_csv('alma.txt', sep='\t')
alma
# Out:
#       OCLC Control Number (035a) Electronic Collection Id  \
# 0                     1011682696        61744128090001701
# 1                     1027540747        61744128090001701
# 2                     1027607053        61744128090001701
# 3                     1027616420        61744128090001701
# 4                     1042906817        61744128090001701
# ...                          ...                      ...
# 6094                   970812547        61744128090001701
# 6095                   970812675        61744128090001701
# 6096                   972783641        61744128090001701
# 6097                   981124646        61744128090001701
# 6098                   999624271        61744128090001701
#
#                         Available For Group
# 0     Crookston; Duluth; Morris; TwinCities
# 1     Crookston; Duluth; Morris; TwinCities
# 2     Crookston; Duluth; Morris; TwinCities
# 3     Crookston; Duluth; Morris; TwinCities
# ...

# %%
alma.rename(columns={"OCLC Control Number (035a)":"ocn"}, inplace = True)

# %%
wcm2.rename(columns={"oclc_number":"ocn"}, inplace = True)
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
report = wcm2.merge(alma, left_on='ocn', right_on='ocn', how='outer')

# %%
report
# Out:
#                                       publication_title  \
# 0     Hydrophobia : M. Pasteur and his methods : a c...
# 1     Oratio panegyrica pro musis Hanovicis instaura...
# 2     Studies in surgical pathological physiology fr...
# 3     Procentische, chemische zusammensetzung der na...
# 4                         Common membranous sore throat
# ...                                                 ...
# 6783  Report of the Departmental Committee appointed...
# 6784  Beitraege zur Kenntniss der normalen und patho...
# 6785  Discussion sur le typhus observé dans les arm...
# 6786         Proceedings of the Royal Society of London
# 6787  A history of nitrous oxide and oxygen anaesthesia
#
#                                               title_url         ocn  \
# 0     https://app.wileydigitalarchives.com/wiley/det...  1159470629
# 1     https://app.wileydigitalarchives.com/wiley/det...  1159507163
# 2     https://app.wileydigitalarchives.com/wiley/det...  1159573078
# ...

# %%
report.to_csv('wcm_rcp_report.txt', sep='\t', index=False)
